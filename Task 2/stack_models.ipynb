# %%
# !pip install matplotlib
# !pip install gymnasium==0.28.1
# !pip install stable_baselines3==2.1.0
# !pip install tqdm

# !pip install gym
# !pip install stable_baselines
# !pip install tensorflow
# !pip install shimmy>=0.2.1
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting gymnasium==0.28.1
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1) (1.23.5)
# Collecting jax-jumpy>=1.0.0 (from gymnasium==0.28.1)
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium==0.28.1)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, jax-jumpy, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-0.28.1 jax-jumpy-1.0.0
# Collecting stable_baselines3==2.1.0
#   Downloading stable_baselines3-2.1.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3==2.1.0) (0.28.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3==2.1.0) (1.23.5)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3==2.1.0) (2.1.0+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3==2.1.0) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3==2.1.0) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3==2.1.0) (3.7.1)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3==2.1.0) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3==2.1.0) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3==2.1.0) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3==2.1.0) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3==2.1.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3==2.1.0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3==2.1.0) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3==2.1.0) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3==2.1.0) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3==2.1.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3==2.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3==2.1.0) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3==2.1.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3==2.1.0) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3==2.1.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3==2.1.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3==2.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3==2.1.0) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3==2.1.0) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable_baselines3==2.1.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable_baselines3==2.1.0) (1.3.0)
# Installing collected packages: stable_baselines3
# Successfully installed stable_baselines3-2.1.0
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.1)
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym) (0.0.8)
# Collecting stable_baselines
#   Downloading stable_baselines-2.10.2-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: gym[atari,classic_control]>=0.11 in /usr/local/lib/python3.10/dist-packages (from stable_baselines) (0.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from stable_baselines) (1.11.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from stable_baselines) (1.3.2)
# Requirement already satisfied: cloudpickle>=0.5.5 in /usr/local/lib/python3.10/dist-packages (from stable_baselines) (2.2.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable_baselines) (4.8.0.76)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stable_baselines) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines) (3.7.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[atari,classic_control]>=0.11->stable_baselines) (0.0.8)
# Collecting pygame==2.1.0 (from gym[atari,classic_control]>=0.11->stable_baselines)
#   Downloading pygame-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 34.3 MB/s eta 0:00:00
# Collecting ale-py~=0.7.5 (from gym[atari,classic_control]>=0.11->stable_baselines)
#   Downloading ale_py-0.7.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 48.3 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines) (2023.3.post1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.7.5->gym[atari,classic_control]>=0.11->stable_baselines) (6.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines) (1.16.0)
# Installing collected packages: pygame, ale-py, stable_baselines
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.5.2
#     Uninstalling pygame-2.5.2:
#       Successfully uninstalled pygame-2.5.2
# Successfully installed ale-py-0.7.5 pygame-2.1.0 stable_baselines-2.10.2
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.59.2)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.41.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)

# %%
import numpy as np
from copy import deepcopy
import matplotlib.pyplot as plt
from tqdm import tqdm
import random
from stable_baselines3 import A2C, DQN, PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback, BaseCallback, StopTrainingOnNoModelImprovement
from stable_baselines3.common.evaluation import evaluate_policy

np.set_printoptions(precision=3)
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/dtypes.py:35: DeprecationWarning: ml_dtypes.float8_e4m3b11 is deprecated. Use ml_dtypes.float8_e4m3b11fnuz
#   from tensorflow.tsl.python.lib.core import pywrap_ml_dtypes

# %%
class StaticAgent:
    def __init__(self, action):
      self.action = action

    def act(self, state):
        return self.action
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
class RandomAgent:
    def __init__(self, risk_level = 0.5):
        self.risk_level = risk_level

    def act(self, state):
      action = random.randint(0, 4)
      if np.random.rand() < self.risk_level:
        action += 5
      return action

# %%
class Car:
    def __init__(self, tyre="Intermediate"):
        self.default_tyre = tyre
        self.possible_tyres = ["Ultrasoft", "Soft", "Intermediate", "Fullwet"]
        self.pitstop_time = 23
        self.reset()


    def reset(self):
        self.change_tyre(self.default_tyre)


    def degrade(self, w, r):
        if self.tyre == "Ultrasoft":
            self.condition *= (1 - 0.0050*w - (2500-r)/90000)
        elif self.tyre == "Soft":
            self.condition *= (1 - 0.0051*w - (2500-r)/93000)
        elif self.tyre == "Intermediate":
            self.condition *= (1 - 0.0052*abs(0.5-w) - (2500-r)/95000)
        elif self.tyre == "Fullwet":
            self.condition *= (1 - 0.0053*(1-w) - (2500-r)/97000)


    def change_tyre(self, new_tyre):
        assert new_tyre in self.possible_tyres
        self.tyre = new_tyre
        self.condition = 1.00


    def get_velocity(self):
        if self.tyre == "Ultrasoft":
            vel = 80.7*(0.2 + 0.8*self.condition**1.5)
        elif self.tyre == "Soft":
            vel = 80.1*(0.2 + 0.8*self.condition**1.5)
        elif self.tyre == "Intermediate":
            vel = 79.5*(0.2 + 0.8*self.condition**1.5)
        elif self.tyre == "Fullwet":
            vel = 79.0*(0.2 + 0.8*self.condition**1.5)
        return vel

# %%
class Track:
    def __init__(self, opponents, mode = "train"):
        # self.radius and self.cur_weather are defined in self.reset()
        self.total_laps = 162
        self.opponents = opponents
        self.mode = mode
        self.cars = [Car() for _ in range(len(self.opponents) + 1)]
        # Target agent's index
        self.target = len(self.opponents)
        self.possible_weather = ["Dry", "20% Wet", "40% Wet", "60% Wet", "80% Wet", "100% Wet"]
        self.wetness = {
            "Dry": 0.00, "20% Wet": 0.20, "40% Wet": 0.40, "60% Wet": 0.60, "80% Wet": 0.80, "100% Wet": 1.00
        }
        self.p_transition = {
            "Dry": {
                "Dry": 0.987, "20% Wet": 0.013, "40% Wet": 0.000, "60% Wet": 0.000, "80% Wet": 0.000, "100% Wet": 0.000
            },
            "20% Wet": {
                "Dry": 0.012, "20% Wet": 0.975, "40% Wet": 0.013, "60% Wet": 0.000, "80% Wet": 0.000, "100% Wet": 0.000
            },
            "40% Wet": {
                "Dry": 0.000, "20% Wet": 0.012, "40% Wet": 0.975, "60% Wet": 0.013, "80% Wet": 0.000, "100% Wet": 0.000
            },
            "60% Wet": {
                "Dry": 0.000, "20% Wet": 0.000, "40% Wet": 0.012, "60% Wet": 0.975, "80% Wet": 0.013, "100% Wet": 0.000
            },
            "80% Wet": {
                "Dry": 0.000, "20% Wet": 0.000, "40% Wet": 0.000, "60% Wet": 0.012, "80% Wet": 0.975, "100% Wet": 0.013
            },
            "100% Wet": {
                "Dry": 0.000, "20% Wet": 0.000, "40% Wet": 0.000, "60% Wet": 0.000, "80% Wet": 0.012, "100% Wet": 0.988
            }
        }
        self.reset()

    def reset(self):
        self.radius = np.random.randint(600,1201)
        self.complexity = [0.00, 0.50, 1.00][np.random.randint(0, 3)]
        self.cur_weather = np.random.choice(self.possible_weather)
        self.is_done = False
        self.pitstops = [False for i in range(len(self.cars))]
        self.laps_cleared = 0
        self.commited_tyres = np.full_like(self.cars, -1)
        self.time_taken = np.zeros_like(self.cars)
        self.actions = [1 for i in range(len(self.cars))]

        for car in self.cars:
          car.reset()
        return self._get_state()

    def _get_state(self):
      return self._get_states()[self.target]

    def _get_states(self):
      qualified = list(filter(lambda x: x is not None, self.time_taken))

      return [
          [
              self.cars[i].tyre,
              self.cars[i].condition,
              self.wetness[self.cur_weather],
              self.radius,
              self.laps_cleared,
              self.complexity,
              None if self.time_taken[i] is None else len(list(filter(lambda x : x < self.time_taken[i], qualified))),
              None if self.time_taken[i] is None else len(list(filter(lambda x : x > self.time_taken[i], qualified))),
          ] for i in range(len(self.cars))]

    def __calculate_reward(self):
      # Disqualified
      if self.time_taken[self.target] is None:
        return 0

      if self.laps_cleared < self.total_laps:
        lap_reward = 1 if self.mode == "train" else 0
        return lap_reward * 0.125
      else:
        qualified = list(filter(lambda x: x is not None, self.time_taken))
        front = len(list(filter(lambda x : x < self.time_taken[self.target], qualified)))
        reward = [1000, 500, 400, 80][min([3, front])]

        if self.mode == "train":
          i = 3
          while front > i:
            reward *= 0.95
            i += 1

        return reward

    def transition(self, action):
        """
        Args:
            action (int):
                0. [Conservative] Make a pitstop and fit new ‘Ultrasoft’ tyres
                1. [Conservative] Make a pitstop and fit new ‘Soft’ tyres
                2. [Conservative] Make a pitstop and fit new ‘Intermediate’ tyres
                3. [Conservative] Make a pitstop and fit new ‘Fullwet’ tyres
                4. [Conservative] Continue the next lap without changing tyres
                5. [Reckless] Make a pitstop and fit new ‘Ultrasoft’ tyres
                6. [Reckless] Make a pitstop and fit new ‘Soft’ tyres
                7. [Reckless] Make a pitstop and fit new ‘Intermediate’ tyres
                8. [Reckless] Make a pitstop and fit new ‘Fullwet’ tyres
                9. [Reckless] Continue the next lap without changing tyres
        """
        self.cur_weather = np.random.choice(
            self.possible_weather, p=list(self.p_transition[self.cur_weather].values())
        )

        states = self._get_states()
        disqualifications = [False for _ in range(len(self.actions))]

        ## The environment is coded such that only an action taken at the start of the three-quarters mark of each lap matters
        if self.laps_cleared - int(self.laps_cleared) == 0.75:
          for i in range(len(self.actions)):
            # Disqualification happens after committing to a strategy for 1 lap
            last_action = self.actions[i]
            accident_rate = 0
            if last_action > 4:
              # Min 1.5%, max 3%
              accident_rate += 0.015 * (1 + self.complexity)
              disqualifications[i] = np.random.rand() < accident_rate

          # Update actions
          for i in range(len(self.opponents)):
            self.actions[i] = self.opponents[i].act(states[i])
          self.actions[-1] = action

        target_velocity = None
        target_reward = None

        ## Pitstop time will be added on the first eight of the subsequent lap
        for i in range(len(self.actions)):
          if self.time_taken[i] is None:
            continue

          time_taken = 0
          action = self.actions[i]
          car = self.cars[i]
          pitstop = self.pitstops[i]
          committed_tyre = self.commited_tyres[i]
          disqualified = disqualifications[i]

          if self.laps_cleared == int(self.laps_cleared):
            if pitstop:
                car.change_tyre(committed_tyre)
                time_taken += car.pitstop_time
                self.pitstops[i] = False

          ## The environment is coded such that only an action taken at the start of the three-quarters mark of each lap matters
          if self.laps_cleared - int(self.laps_cleared) == 0.75:
            if action % 5 < 4:
              self.pitstops[i] = True
              self.commited_tyres[i] = car.possible_tyres[action % 5]
            else:
              self.pitstops[i] = False

          # we assume that degration happens only after a car has travelled the one-eighth lap
          velocity = car.get_velocity()
          if action > 4:
            velocity *= 1.1
          time_taken += (2 * np.pi * self.radius / 8) / velocity
          reward = 0 - time_taken

          car.degrade(
              w = self.wetness[self.cur_weather], r=self.radius
          )

          if disqualified:
            self.time_taken[i] = None
          else:
            self.time_taken[i] += time_taken
            # self.time_taken[i] += Decimal(time_taken)

          if i == self.target:
            target_velocity = -1 if disqualified else velocity

        self.laps_cleared += 0.125

        if self.laps_cleared == self.total_laps or disqualified:
          self.is_done = True

        next_state = self._get_state()
        return self.__calculate_reward(), next_state, self.is_done, target_velocity

# %%
env = Track([StaticAgent(1),StaticAgent(1), StaticAgent(1), StaticAgent(1), StaticAgent(1)], mode="train")

agent = StaticAgent(5)

# %%
state = env.reset()
print(state)
done = False
G = 0
while not done:
    action = agent.act(state)
    reward, next_state, done, velocity = env.transition(action)
    # added velocity for sanity check
    state = deepcopy(next_state)
    G += reward
print(state)
print("G: ", G)
# Out:
# ['Intermediate', 1.0, 0.6, 694, 0, 0.5, 0, 0]
# ['Ultrasoft', 0.8371907771855044, 1.0, 694, 10.875, 0.5, None, None]
# G:  10.75

# %% [markdown]
# ## Library Testing

# %% [markdown]
# Other algos to try:
# https://stable-baselines3.readthedocs.io/en/master/guide/algos.html

# %%
from google.colab import drive

drive.mount("/content/drive")
# %cd drive/My Drive/Colab Notebooks/Task 2 - Final
# %ls
# Out:
# /usr/local/lib/python3.10/dist-packages/pexpect/popen_spawn.py:60: DeprecationWarning: setDaemon() is deprecated, set the daemon attribute instead
#   self._read_thread.setDaemon(True)
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks/Task 2 - Final
# base_model/  dqn.ipynb         split_models/       stack_models/
# dqn/         evaluation.ipynb  split_models.ipynb  stack_models.ipynb

# %%
import gym
from gym import spaces
import numpy as np

class RaceTrackEnv(gym.Env):
    def __init__(self, agents, base_model, mode):
        self.track = Track(agents, mode=mode)
        self.base_model = base_model

        # Action space: 10 discrete actions
        self.action_space = spaces.Discrete(10)

        # Flattened observation space
        max_radius = 1200
        max_laps = self.track.total_laps
        self.observation_space = spaces.Box(
            low=np.array([0, 0, 0, 0, 600, 0, 0, 0, 0]),
            high=np.array([4, 3, 1, 5, max_radius, max_laps, 1, len(agents), len(agents)]),
            dtype=np.float32
        )

    def _transform_state(self, tyre, condition, wetness, radius, laps_cleared, complexity, front, back):
      tyre = float(Car().possible_tyres.index(tyre))
      action, _ = self.base_model.predict(np.array([tyre, condition, wetness, radius, laps_cleared]))
      return np.array([
          int(action),
          tyre,
          condition,
          wetness,
          radius,
          laps_cleared,
          complexity,
          front,
          back
      ])

    def step(self, action):
      reward, next_state, done, velocity = self.track.transition(action)
      tyre, condition, wetness, radius, laps_cleared, complexity, front, back = next_state
      r = reward

      while laps_cleared - int(laps_cleared) != 0.75:
        if done:
          break
        reward, next_state, done, velocity = self.track.transition(action)
        tyre, condition, wetness, radius, laps_cleared, complexity, front, back = next_state
        r += reward

      return self._transform_state(tyre, condition, wetness, radius, laps_cleared, complexity, front, back), r, done, {"velocity": velocity}

    def reset(self):
        tyre, condition, wetness, radius, laps_cleared, complexity, front, back = self.track.reset()

        # Starts at 0.75
        while laps_cleared < 0.75:
          reward, next_state, done, velocity = self.track.transition(0)
          tyre, condition, wetness, radius, laps_cleared, complexity, front, back = next_state

        return self._transform_state(tyre, condition, wetness, radius, laps_cleared, complexity, front, back)

    def render(self, mode="human"):
      tyre, condition, wetness, radius, laps_cleared, complexity, front, back = self.track._get_state()
      # Simple rendering using print statements.
      print(f"Tyre: {tyre}, Condition: {condition:.2f}, Wetness: {wetness}, Radius: {radius}, Laps Cleared: {laps_cleared}, Complexity: {complexity}, Cars in front: {front}, Cars behind: {back}")

    def close(self):
        pass

# %%
class Sb3Agent:
  def _transform_state(self, tyre, condition, wetness, radius, laps_cleared, complexity, front, back):
    return float(Car().possible_tyres.index(tyre)), condition, wetness, radius, laps_cleared, complexity, front, back

# %%
class ProbabilityBasedAgent(Sb3Agent):
  def __init__(self, model, risk_level=0):
    self.model = model
    self.risk_level = risk_level

  def act(self, state):
    tyre, condition, wetness, radius, laps_cleared, complexity, front, back = state
    tyre, condition, wetness, radius, laps_cleared, complexity, front, back = self._transform_state(tyre, condition, wetness, radius, laps_cleared, complexity, front, back)
    if front is None or back is None: # Disqualifeid
      return 4
    else:
      action, _ = self.model.predict(np.array([tyre, condition, wetness, radius, laps_cleared]))
      action = int(action)

      if np.random.rand() < self.risk_level:
        action += 5

      return action

# %%
dir = "/stack_models"

# %%
base_model = DQN.load("./base_model/best_model.zip", verbose=0)

agents = [
    StaticAgent(0),
    ProbabilityBasedAgent(base_model),
    ProbabilityBasedAgent(base_model, risk_level=0.05),
    ProbabilityBasedAgent(base_model, risk_level=0.1),
    ProbabilityBasedAgent(base_model, risk_level=0.2),
    RandomAgent(risk_level=0),
    RandomAgent(risk_level=0.05),
    RandomAgent(risk_level=0.1),
    RandomAgent(risk_level=0.2),
    ]

# %%
env = RaceTrackEnv(agents, base_model, mode="train")

try:
    stack_model = DQN.load(f".{dir}/best_model.zip", env=env, verbose=0)
    print("Model loaded from:", f".{dir}/best_model.zip")
except:
  print("Initializing model ...")
  stack_model = DQN("MlpPolicy", env, verbose=0)
# Out:
# Initializing model ...
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
class TrainingMonitorCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(TrainingMonitorCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.total_rewards = 0
        self.total_episodes = 0

    def _on_step(self) -> bool:
        if 'episode' in self.locals['infos'][0].keys():
          reward = self.locals['infos'][0]['episode']['r']
          self.total_rewards += reward
          self.total_episodes += 1
          self.episode_rewards.append(self.total_rewards / self.total_episodes)
        return True

# %%
eval_env = RaceTrackEnv(agents, base_model, mode="test")
monitor = TrainingMonitorCallback()
stack_model.learn(
    total_timesteps=10000000,
    callback=[
        monitor,
        EvalCallback(
          eval_env,
          best_model_save_path=f".{dir}/",
          eval_freq=2000,
          n_eval_episodes=50,
          callback_after_eval=StopTrainingOnNoModelImprovement(max_no_improvement_evals=50, min_evals=100, verbose=0)
        )
    ]
)
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=2000, episode_reward=226.51 +/- 3.48
# Episode length: 162.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=4000, episode_reward=226.94 +/- 3.90
# Episode length: 162.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=6000, episode_reward=228.59 +/- 4.26
# Episode length: 162.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=8000, episode_reward=226.70 +/- 4.42
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=10000, episode_reward=226.26 +/- 3.75
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=12000, episode_reward=226.08 +/- 4.14
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=14000, episode_reward=225.87 +/- 3.90
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=16000, episode_reward=226.13 +/- 3.88
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=18000, episode_reward=227.20 +/- 3.74
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=20000, episode_reward=226.75 +/- 4.14
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=22000, episode_reward=226.50 +/- 4.42
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=24000, episode_reward=226.45 +/- 3.51
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=26000, episode_reward=226.55 +/- 4.13
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=28000, episode_reward=227.40 +/- 3.69
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=30000, episode_reward=227.23 +/- 4.25
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=32000, episode_reward=226.81 +/- 4.04
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=34000, episode_reward=227.32 +/- 4.62
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=36000, episode_reward=226.59 +/- 3.62
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=38000, episode_reward=227.30 +/- 4.29
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=40000, episode_reward=225.96 +/- 4.31
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=42000, episode_reward=226.37 +/- 3.43
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=44000, episode_reward=226.21 +/- 4.11
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=46000, episode_reward=226.66 +/- 3.85
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=48000, episode_reward=227.17 +/- 3.27
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=50000, episode_reward=226.57 +/- 4.55
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=52000, episode_reward=237.51 +/- 46.50
# Episode length: 162.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=54000, episode_reward=230.16 +/- 4.72
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=56000, episode_reward=230.31 +/- 4.83
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=58000, episode_reward=230.49 +/- 4.42
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=60000, episode_reward=244.98 +/- 64.70
# Episode length: 162.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=62000, episode_reward=244.23 +/- 64.82
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=64000, episode_reward=244.70 +/- 64.77
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=66000, episode_reward=231.31 +/- 3.79
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=68000, episode_reward=231.94 +/- 4.75
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=70000, episode_reward=237.14 +/- 46.53
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=72000, episode_reward=231.03 +/- 3.94
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=74000, episode_reward=231.09 +/- 4.89
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=76000, episode_reward=237.84 +/- 46.40
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=78000, episode_reward=232.43 +/- 4.34
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=80000, episode_reward=230.88 +/- 3.76
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=82000, episode_reward=244.39 +/- 64.80
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=84000, episode_reward=247.21 +/- 75.11
# Episode length: 162.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=86000, episode_reward=231.25 +/- 4.07
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=88000, episode_reward=238.82 +/- 46.33
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=90000, episode_reward=246.52 +/- 75.21
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=92000, episode_reward=245.30 +/- 64.59
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=94000, episode_reward=232.41 +/- 4.05
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=96000, episode_reward=231.71 +/- 4.51
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=98000, episode_reward=238.03 +/- 46.34
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=100000, episode_reward=237.21 +/- 46.41
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=102000, episode_reward=230.70 +/- 4.34
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=104000, episode_reward=239.43 +/- 60.44
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=106000, episode_reward=230.23 +/- 4.71
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=108000, episode_reward=236.39 +/- 46.57
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=110000, episode_reward=232.09 +/- 4.79
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=112000, episode_reward=231.68 +/- 3.93
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=114000, episode_reward=231.85 +/- 4.41
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=116000, episode_reward=230.62 +/- 4.27
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=118000, episode_reward=238.86 +/- 60.51
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=120000, episode_reward=231.93 +/- 4.59
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=122000, episode_reward=237.19 +/- 46.49
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=124000, episode_reward=231.21 +/- 4.50
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=126000, episode_reward=243.73 +/- 64.92
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=128000, episode_reward=244.05 +/- 64.89
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=130000, episode_reward=238.33 +/- 46.32
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=132000, episode_reward=232.32 +/- 3.80
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=134000, episode_reward=230.71 +/- 4.48
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=136000, episode_reward=230.57 +/- 4.54
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=138000, episode_reward=231.46 +/- 5.01
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=140000, episode_reward=238.75 +/- 46.24
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=142000, episode_reward=230.44 +/- 4.67
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=144000, episode_reward=230.39 +/- 3.94
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=146000, episode_reward=244.46 +/- 64.79
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=148000, episode_reward=232.18 +/- 4.99
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=150000, episode_reward=238.27 +/- 46.34
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=152000, episode_reward=230.96 +/- 4.02
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=154000, episode_reward=237.67 +/- 46.39
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=156000, episode_reward=230.91 +/- 4.33
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=158000, episode_reward=230.99 +/- 4.36
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=160000, episode_reward=230.19 +/- 4.13
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=162000, episode_reward=231.51 +/- 4.71
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=164000, episode_reward=230.54 +/- 4.12
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=166000, episode_reward=238.64 +/- 46.31
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=168000, episode_reward=231.39 +/- 5.05
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=170000, episode_reward=238.39 +/- 46.30
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=172000, episode_reward=238.12 +/- 46.36
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=174000, episode_reward=237.24 +/- 46.44
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=176000, episode_reward=231.01 +/- 4.72
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=178000, episode_reward=231.08 +/- 4.69
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=180000, episode_reward=231.61 +/- 3.92
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=182000, episode_reward=230.89 +/- 5.07
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=184000, episode_reward=231.23 +/- 4.86
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=186000, episode_reward=230.03 +/- 3.74
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=188000, episode_reward=232.12 +/- 5.13
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=190000, episode_reward=237.33 +/- 46.46
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=192000, episode_reward=231.78 +/- 4.43
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=194000, episode_reward=236.54 +/- 46.56
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=196000, episode_reward=230.92 +/- 4.47
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=198000, episode_reward=231.69 +/- 4.09
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=200000, episode_reward=237.09 +/- 46.46
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=202000, episode_reward=237.34 +/- 46.48
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=204000, episode_reward=232.40 +/- 3.79
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=206000, episode_reward=231.51 +/- 4.75
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=208000, episode_reward=238.65 +/- 46.31
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=210000, episode_reward=245.09 +/- 64.64
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=212000, episode_reward=238.85 +/- 46.27
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=214000, episode_reward=231.96 +/- 3.85
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=216000, episode_reward=245.57 +/- 64.59
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=218000, episode_reward=236.45 +/- 46.54
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=220000, episode_reward=231.22 +/- 4.64
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=222000, episode_reward=244.20 +/- 64.80
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=224000, episode_reward=236.55 +/- 46.57
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=226000, episode_reward=236.73 +/- 46.61
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=228000, episode_reward=230.78 +/- 4.55
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=230000, episode_reward=237.22 +/- 46.53
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=232000, episode_reward=230.57 +/- 4.48
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=234000, episode_reward=243.82 +/- 64.93
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=236000, episode_reward=230.35 +/- 4.46
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=238000, episode_reward=231.14 +/- 4.44
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=240000, episode_reward=231.82 +/- 4.99
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=242000, episode_reward=237.14 +/- 46.52
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=244000, episode_reward=237.66 +/- 46.48
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=246000, episode_reward=239.37 +/- 46.20
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=248000, episode_reward=252.50 +/- 87.26
# Episode length: 162.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=250000, episode_reward=231.30 +/- 4.72
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=252000, episode_reward=231.28 +/- 4.50
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=254000, episode_reward=238.30 +/- 46.38
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=256000, episode_reward=244.52 +/- 64.77
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=258000, episode_reward=237.85 +/- 46.41
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=260000, episode_reward=244.25 +/- 64.84
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=262000, episode_reward=237.49 +/- 46.47
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=264000, episode_reward=257.11 +/- 89.79
# Episode length: 162.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=266000, episode_reward=238.39 +/- 46.29
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=268000, episode_reward=238.80 +/- 46.30
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=270000, episode_reward=231.43 +/- 4.62
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=272000, episode_reward=232.55 +/- 5.05
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=274000, episode_reward=231.10 +/- 3.94
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=276000, episode_reward=229.95 +/- 4.74
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=278000, episode_reward=230.98 +/- 4.18
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=280000, episode_reward=232.72 +/- 4.30
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=282000, episode_reward=231.05 +/- 4.19
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=284000, episode_reward=231.80 +/- 4.76
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=286000, episode_reward=238.21 +/- 46.37
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=288000, episode_reward=239.52 +/- 60.36
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=290000, episode_reward=231.24 +/- 5.02
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=292000, episode_reward=236.90 +/- 46.52
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=294000, episode_reward=230.62 +/- 4.16
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=296000, episode_reward=237.12 +/- 46.51
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=298000, episode_reward=230.93 +/- 4.65
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=300000, episode_reward=231.19 +/- 4.16
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=302000, episode_reward=230.83 +/- 5.20
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=304000, episode_reward=231.38 +/- 4.86
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=306000, episode_reward=231.69 +/- 5.26
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=308000, episode_reward=244.16 +/- 64.83
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=310000, episode_reward=232.44 +/- 4.51
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=312000, episode_reward=230.72 +/- 4.72
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=314000, episode_reward=237.18 +/- 46.47
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=316000, episode_reward=230.64 +/- 4.50
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=318000, episode_reward=230.93 +/- 4.61
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=320000, episode_reward=231.07 +/- 4.48
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=322000, episode_reward=237.54 +/- 46.43
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=324000, episode_reward=231.48 +/- 4.17
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=326000, episode_reward=238.33 +/- 46.31
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=328000, episode_reward=237.25 +/- 46.47
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=330000, episode_reward=231.82 +/- 5.05
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=332000, episode_reward=231.07 +/- 4.58
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=334000, episode_reward=231.60 +/- 4.94
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=336000, episode_reward=231.37 +/- 4.76
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=338000, episode_reward=231.83 +/- 4.14
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=340000, episode_reward=230.73 +/- 4.86
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=342000, episode_reward=230.60 +/- 5.03
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=344000, episode_reward=230.57 +/- 4.49
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=346000, episode_reward=230.40 +/- 4.12
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=348000, episode_reward=232.18 +/- 4.96
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=350000, episode_reward=237.82 +/- 46.38
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=352000, episode_reward=237.69 +/- 46.41
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=354000, episode_reward=230.48 +/- 4.21
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=356000, episode_reward=230.72 +/- 3.44
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=358000, episode_reward=231.31 +/- 3.84
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=360000, episode_reward=237.54 +/- 46.43
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=362000, episode_reward=237.78 +/- 46.43
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=364000, episode_reward=238.48 +/- 46.31
# Episode length: 162.00 +/- 0.00
# Eval num_timesteps=366000, episode_reward=240.18 +/- 60.37
# Episode length: 162.00 +/- 0.00

# %%
stack_model.save(f".{dir}/stack_models.zip")

# %%
def plot_training_results(rewards, title='Training Results'):
    plt.plot(rewards)
    plt.xlabel('Episodes')
    plt.ylabel('Average Rewards')
    plt.title(title)
    plt.show()

plot_training_results(monitor.episode_rewards, title='Stack Models Training Results')
