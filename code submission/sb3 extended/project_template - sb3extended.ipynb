# %%
# !pip install matplotlib
# !pip install gymnasium==0.28.1
# !pip install stable_baselines3==2.1.0
# !pip install tqdm

# !pip install gym
# !pip install stable_baselines
# !pip install tensorflow
# !pip install shimmy>=0.2.1

# %%
import numpy as np
from copy import deepcopy
import matplotlib.pyplot as plt
from tqdm import tqdm

np.set_printoptions(precision=3)

# %%
class Agent:
    def __init__(self):
        pass
    
    def act(self, state):
        # Simple-minded agent that always select action 1
        return 1

# %%
class Car:
    def __init__(self, tyre="Intermediate"):
        self.default_tyre = tyre
        self.possible_tyres = ["Ultrasoft", "Soft", "Intermediate", "Fullwet"]
        self.pitstop_time = 23
        self.reset()
    
    
    def reset(self):
        self.change_tyre(self.default_tyre)
    
    
    def degrade(self, w, r):
        if self.tyre == "Ultrasoft":
            self.condition *= (1 - 0.0050*w - (2500-r)/90000)
        elif self.tyre == "Soft":
            self.condition *= (1 - 0.0051*w - (2500-r)/93000)
        elif self.tyre == "Intermediate":
            self.condition *= (1 - 0.0052*abs(0.5-w) - (2500-r)/95000)
        elif self.tyre == "Fullwet":
            self.condition *= (1 - 0.0053*(1-w) - (2500-r)/97000)
        
        
    def change_tyre(self, new_tyre):
        assert new_tyre in self.possible_tyres
        self.tyre = new_tyre
        self.condition = 1.00
    
    
    def get_velocity(self):
        if self.tyre == "Ultrasoft":
            vel = 80.7*(0.2 + 0.8*self.condition**1.5)
        elif self.tyre == "Soft":
            vel = 80.1*(0.2 + 0.8*self.condition**1.5)
        elif self.tyre == "Intermediate":
            vel = 79.5*(0.2 + 0.8*self.condition**1.5)
        elif self.tyre == "Fullwet":
            vel = 79.0*(0.2 + 0.8*self.condition**1.5)
        return vel

    
class Track:
    def __init__(self, car=Car()):
        # self.radius and self.cur_weather are defined in self.reset()
        self.total_laps = 162
        self.car = car
        self.possible_weather = ["Dry", "20% Wet", "40% Wet", "60% Wet", "80% Wet", "100% Wet"]
        self.wetness = {
            "Dry": 0.00, "20% Wet": 0.20, "40% Wet": 0.40, "60% Wet": 0.60, "80% Wet": 0.80, "100% Wet": 1.00
        }
        self.p_transition = {
            "Dry": {
                "Dry": 0.987, "20% Wet": 0.013, "40% Wet": 0.000, "60% Wet": 0.000, "80% Wet": 0.000, "100% Wet": 0.000
            },
            "20% Wet": {
                "Dry": 0.012, "20% Wet": 0.975, "40% Wet": 0.013, "60% Wet": 0.000, "80% Wet": 0.000, "100% Wet": 0.000
            },
            "40% Wet": {
                "Dry": 0.000, "20% Wet": 0.012, "40% Wet": 0.975, "60% Wet": 0.013, "80% Wet": 0.000, "100% Wet": 0.000
            },
            "60% Wet": {
                "Dry": 0.000, "20% Wet": 0.000, "40% Wet": 0.012, "60% Wet": 0.975, "80% Wet": 0.013, "100% Wet": 0.000
            },
            "80% Wet": {
                "Dry": 0.000, "20% Wet": 0.000, "40% Wet": 0.000, "60% Wet": 0.012, "80% Wet": 0.975, "100% Wet": 0.013
            },
            "100% Wet": {
                "Dry": 0.000, "20% Wet": 0.000, "40% Wet": 0.000, "60% Wet": 0.000, "80% Wet": 0.012, "100% Wet": 0.988
            }
        }
        self.reset()
    
    
    def reset(self):
        # self.radius = np.random.randint(600,1201)
        self.radius = 900
        self.cur_weather = np.random.choice(self.possible_weather)
        self.is_done = False
        self.pitstop = False
        self.laps_cleared = 0
        self.car.reset()
        return self._get_state()
    
    
    def _get_state(self):
        return [self.car.tyre, self.car.condition, self.cur_weather, self.radius, self.laps_cleared]
        
    
    def transition(self, action=0):
        """
        Args:
            action (int):
                0. Make a pitstop and fit new ‘Ultrasoft’ tyres
                1. Make a pitstop and fit new ‘Soft’ tyres
                2. Make a pitstop and fit new ‘Intermediate’ tyres
                3. Make a pitstop and fit new ‘Fullwet’ tyres
                4. Continue the next lap without changing tyres
        """
        ## Pitstop time will be added on the first eight of the subsequent lap
        if self.laps_cleared - int(self.laps_cleared) == 0.75 and self.laps_cleared < 161.75:
            total_rewards = 0
            for _ in range(8):
                time_taken = 0
                if self.laps_cleared == int(self.laps_cleared):
                    if self.pitstop:
                        self.car.change_tyre(self.committed_tyre)
                        time_taken += self.car.pitstop_time
                        self.pitstop = False
                
                ## The environment is coded such that only an action taken at the start of the three-quarters mark of each lap matters
                if self.laps_cleared - int(self.laps_cleared) == 0.75:
                    if action < 4:
                        self.pitstop = True
                        self.committed_tyre = self.car.possible_tyres[action]
                    else:
                        self.pitstop = False
                
                self.cur_weather = np.random.choice(
                    self.possible_weather, p=list(self.p_transition[self.cur_weather].values())
                )
                # we assume that degration happens only after a car has travelled the one-eighth lap
                velocity = self.car.get_velocity()
                time_taken += (2*np.pi*self.radius/8) / velocity
                reward = 0 - time_taken
                self.car.degrade(
                    w=self.wetness[self.cur_weather], r=self.radius
                )
                self.laps_cleared += 0.125
                
                if self.laps_cleared == self.total_laps:
                    self.is_done = True
                
                total_rewards += reward
                next_state = self._get_state()
                
            return total_rewards, next_state, self.is_done, velocity
        
        else:
            time_taken = 0
            if self.laps_cleared == int(self.laps_cleared):
                if self.pitstop:
                    self.car.change_tyre(self.committed_tyre)
                    time_taken += self.car.pitstop_time
                    self.pitstop = False
            
            ## The environment is coded such that only an action taken at the start of the three-quarters mark of each lap matters
            if self.laps_cleared - int(self.laps_cleared) == 0.75:
                if action < 4:
                    self.pitstop = True
                    self.committed_tyre = self.car.possible_tyres[action]
                else:
                    self.pitstop = False
            
            self.cur_weather = np.random.choice(
                self.possible_weather, p=list(self.p_transition[self.cur_weather].values())
            )
            # we assume that degration happens only after a car has travelled the one-eighth lap
            velocity = self.car.get_velocity()
            time_taken += (2*np.pi*self.radius/8) / velocity
            reward = 0 - time_taken
            self.car.degrade(
                w=self.wetness[self.cur_weather], r=self.radius
            )
            self.laps_cleared += 0.125
            
            if self.laps_cleared == self.total_laps:
                self.is_done = True
            
            next_state = self._get_state()
            return reward, next_state, self.is_done, velocity

# %%
new_car = Car()
env = Track(new_car)

agent = Agent()

# %%
state = env.reset()    
done = False
G = 0
while not done:
    action = agent.act(state)
    reward, next_state, done, velocity = env.transition(action)
    # added velocity for sanity check
    state = deepcopy(next_state)
    G += reward

print("G: %d" % G)
# Out:
# G: -16234

# %% [markdown]
# ### Race 1

# %%
# Store historical weather
holder = []

state = env.reset()
start_state = deepcopy(state)
done = False
G = 0
while not done:
    holder.append(env.cur_weather)
    action = agent.act(state)
    reward, next_state, done, velocity = env.transition(action)
    # added velocity for sanity check
    state = deepcopy(next_state)
    G += reward

# %%
group1 = Agent()
group2 = Agent()
group3 = Agent()
group4 = Agent()
group5 = Agent()
group6 = Agent()
group7 = Agent()
group8 = Agent()
group9 = Agent()

# %%
# Race 1
start_weather, radius = start_state[2], start_state[3]

for agent in [group1, group2, group3, group4, group5, group6, group7, group8, group9]:
    state = env.reset() 
    env.cur_weather = start_weather   # assert common start weather
    env.radius = radius               # assert common track radius
    done = False
    G = 0
    i = 0
    while not done:
        env.cur_weather = holder[i]   # assert weather transition
        action = agent.act(state)
        reward, next_state, done, velocity = env.transition(action)
        # added velocity for sanity check
        state = deepcopy(next_state)
        G += reward
        i += 1
    
    print("G: %.2f" % G)
# Out:
# G: -16219.58
# G: -16220.18
# G: -16221.07
# G: -16221.65
# G: -16220.11
# G: -16219.40
# G: -16221.14
# G: -16220.56
# G: -16219.43

# %% [markdown]
# ## Library Testing

# %% [markdown]
# Other algos to try:
# https://stable-baselines3.readthedocs.io/en/master/guide/algos.html

# %%
import gym
from gym import spaces
import numpy as np

class RaceTrackEnv(gym.Env):
    def __init__(self):
        self.track = Track()
        
        # Action space: 5 discrete actions
        self.action_space = spaces.Discrete(5)
        
        # Flattened observation space
        max_radius = 1200
        max_laps = self.track.total_laps
        self.observation_space = spaces.Box(
            low=np.array([0, 0, 0, 600, 0]), 
            high=np.array([3, 1, 5, max_radius, max_laps]), 
            dtype=np.float32
        )
        
    def step(self, action):
        reward, next_state, done, velocity = self.track.transition(action)
        
        # Convert the tyre type from a string to an integer index for the observation space
        tyre_idx = float(self.track.car.possible_tyres.index(next_state[0]))
        weather_idx = float(self.track.possible_weather.index(next_state[2]))
        
        # Convert the observation to a flattened format
        obs = np.array([tyre_idx, next_state[1], weather_idx, float(next_state[3]), next_state[4]])
        # print(reward)
        return obs, reward, done, {"velocity": velocity}
        
    def reset(self):
        state = self.track.reset()
        tyre_idx = float(self.track.car.possible_tyres.index(state[0]))
        weather_idx = float(self.track.possible_weather.index(state[2]))
        return np.array([tyre_idx, 1.00, weather_idx, float(state[3]), state[4]])

    def render(self, mode="human"):
        # Simple rendering using print statements.
        state = self.track._get_state()
        # if int(state[4])==state[4]:
        #     print(f"Tyre: {state[0]}, Condition: {state[1]:.2f}, Weather: {state[2]}, Radius: {state[3]}, Laps Cleared: {state[4]:.2f}")
        print(f"Tyre: {state[0]}, Condition: {state[1]:.2f}, Weather: {state[2]}, Radius: {state[3]}, Laps Cleared: {state[4]:.2f}")
        
    def close(self):
        pass

# %%
# You can then use the environment as:
env = RaceTrackEnv()
obs = env.reset()
for _ in range(8*162): #1000 eighths of a lap
    action = env.action_space.sample() # Take random action as an example
    obs, reward, done, info = env.step(action)
    env.render()
    if done:
        break
# Out:
# Tyre: Intermediate, Condition: 0.98, Weather: 40% Wet, Radius: 900, Laps Cleared: 0.12
# Tyre: Intermediate, Condition: 0.97, Weather: 40% Wet, Radius: 900, Laps Cleared: 0.25
# Tyre: Intermediate, Condition: 0.95, Weather: 40% Wet, Radius: 900, Laps Cleared: 0.38
# Tyre: Intermediate, Condition: 0.93, Weather: 40% Wet, Radius: 900, Laps Cleared: 0.50
# Tyre: Intermediate, Condition: 0.92, Weather: 40% Wet, Radius: 900, Laps Cleared: 0.62
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 0.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 1.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 2.75
# Tyre: Fullwet, Condition: 0.77, Weather: 60% Wet, Radius: 900, Laps Cleared: 3.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 4.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 5.75
# Tyre: Ultrasoft, Condition: 0.76, Weather: 40% Wet, Radius: 900, Laps Cleared: 6.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 7.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 8.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 9.75
# Tyre: Soft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 10.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 11.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 12.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 13.75
# Tyre: Soft, Condition: 0.90, Weather: 20% Wet, Radius: 900, Laps Cleared: 14.75
# Tyre: Soft, Condition: 0.90, Weather: 20% Wet, Radius: 900, Laps Cleared: 15.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 16.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 17.75
# Tyre: Fullwet, Condition: 0.75, Weather: 20% Wet, Radius: 900, Laps Cleared: 18.75
# Tyre: Fullwet, Condition: 0.63, Weather: 20% Wet, Radius: 900, Laps Cleared: 19.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 20.75
# Tyre: Fullwet, Condition: 0.75, Weather: 20% Wet, Radius: 900, Laps Cleared: 21.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 22.75
# Tyre: Ultrasoft, Condition: 0.77, Weather: 20% Wet, Radius: 900, Laps Cleared: 23.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 24.75
# Tyre: Soft, Condition: 0.90, Weather: 20% Wet, Radius: 900, Laps Cleared: 25.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 26.75
# Tyre: Soft, Condition: 0.90, Weather: 20% Wet, Radius: 900, Laps Cleared: 27.75
# Tyre: Soft, Condition: 0.90, Weather: 20% Wet, Radius: 900, Laps Cleared: 28.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 29.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 30.75
# Tyre: Soft, Condition: 0.90, Weather: 20% Wet, Radius: 900, Laps Cleared: 31.75
# Tyre: Soft, Condition: 0.90, Weather: 20% Wet, Radius: 900, Laps Cleared: 32.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 33.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 34.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 35.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 36.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 37.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 38.75
# Tyre: Ultrasoft, Condition: 0.76, Weather: 40% Wet, Radius: 900, Laps Cleared: 39.75
# Tyre: Ultrasoft, Condition: 0.64, Weather: 40% Wet, Radius: 900, Laps Cleared: 40.75
# Tyre: Ultrasoft, Condition: 0.55, Weather: 40% Wet, Radius: 900, Laps Cleared: 41.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 42.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 43.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 44.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 45.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 46.75
# Tyre: Ultrasoft, Condition: 0.75, Weather: 60% Wet, Radius: 900, Laps Cleared: 47.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 48.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 49.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 50.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 51.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 52.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 53.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 54.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 55.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 56.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 57.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 58.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 59.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 60.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 61.75
# Tyre: Soft, Condition: 0.74, Weather: 80% Wet, Radius: 900, Laps Cleared: 62.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 63.75
# Tyre: Intermediate, Condition: 0.89, Weather: 80% Wet, Radius: 900, Laps Cleared: 64.75
# Tyre: Intermediate, Condition: 0.77, Weather: 80% Wet, Radius: 900, Laps Cleared: 65.75
# Tyre: Intermediate, Condition: 0.67, Weather: 60% Wet, Radius: 900, Laps Cleared: 66.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 67.75
# Tyre: Intermediate, Condition: 0.78, Weather: 60% Wet, Radius: 900, Laps Cleared: 68.75
# Tyre: Intermediate, Condition: 0.68, Weather: 80% Wet, Radius: 900, Laps Cleared: 69.75
# Tyre: Intermediate, Condition: 0.89, Weather: 80% Wet, Radius: 900, Laps Cleared: 70.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 71.75
# Tyre: Soft, Condition: 0.74, Weather: 80% Wet, Radius: 900, Laps Cleared: 72.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 73.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 74.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 75.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 76.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 77.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 78.75
# Tyre: Fullwet, Condition: 0.79, Weather: 100% Wet, Radius: 900, Laps Cleared: 79.75
# Tyre: Fullwet, Condition: 0.69, Weather: 100% Wet, Radius: 900, Laps Cleared: 80.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 81.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 82.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 83.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 84.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 85.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 86.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 87.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 88.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 89.75
# Tyre: Intermediate, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 90.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 91.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 92.75
# Tyre: Intermediate, Condition: 0.89, Weather: 80% Wet, Radius: 900, Laps Cleared: 93.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 94.75
# Tyre: Soft, Condition: 0.88, Weather: 100% Wet, Radius: 900, Laps Cleared: 95.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 96.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 97.75
# Tyre: Soft, Condition: 0.73, Weather: 80% Wet, Radius: 900, Laps Cleared: 98.75
# Tyre: Intermediate, Condition: 0.89, Weather: 80% Wet, Radius: 900, Laps Cleared: 99.75
# Tyre: Intermediate, Condition: 0.77, Weather: 80% Wet, Radius: 900, Laps Cleared: 100.75
# Tyre: Intermediate, Condition: 0.89, Weather: 80% Wet, Radius: 900, Laps Cleared: 101.75
# Tyre: Intermediate, Condition: 0.77, Weather: 80% Wet, Radius: 900, Laps Cleared: 102.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 103.75
# Tyre: Intermediate, Condition: 0.78, Weather: 60% Wet, Radius: 900, Laps Cleared: 104.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 105.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 106.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 107.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 108.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 109.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 110.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 111.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 112.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 113.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 114.75
# Tyre: Intermediate, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 115.75
# Tyre: Intermediate, Condition: 0.77, Weather: 80% Wet, Radius: 900, Laps Cleared: 116.75
# Tyre: Intermediate, Condition: 0.67, Weather: 80% Wet, Radius: 900, Laps Cleared: 117.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 118.75
# Tyre: Fullwet, Condition: 0.90, Weather: 100% Wet, Radius: 900, Laps Cleared: 119.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 120.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 121.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 122.75
# Tyre: Ultrasoft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 123.75
# Tyre: Ultrasoft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 124.75
# Tyre: Ultrasoft, Condition: 0.72, Weather: 100% Wet, Radius: 900, Laps Cleared: 125.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 126.75
# Tyre: Ultrasoft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 127.75
# Tyre: Ultrasoft, Condition: 0.72, Weather: 100% Wet, Radius: 900, Laps Cleared: 128.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 129.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 130.75
# Tyre: Intermediate, Condition: 0.76, Weather: 80% Wet, Radius: 900, Laps Cleared: 131.75
# Tyre: Intermediate, Condition: 0.89, Weather: 80% Wet, Radius: 900, Laps Cleared: 132.75
# Tyre: Intermediate, Condition: 0.89, Weather: 80% Wet, Radius: 900, Laps Cleared: 133.75
# Tyre: Intermediate, Condition: 0.89, Weather: 80% Wet, Radius: 900, Laps Cleared: 134.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 135.75
# Tyre: Intermediate, Condition: 0.76, Weather: 100% Wet, Radius: 900, Laps Cleared: 136.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 137.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 138.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 139.75
# Tyre: Intermediate, Condition: 0.89, Weather: 80% Wet, Radius: 900, Laps Cleared: 140.75
# Tyre: Intermediate, Condition: 0.77, Weather: 80% Wet, Radius: 900, Laps Cleared: 141.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 142.75
# Tyre: Soft, Condition: 0.74, Weather: 60% Wet, Radius: 900, Laps Cleared: 143.75
# Tyre: Soft, Condition: 0.63, Weather: 40% Wet, Radius: 900, Laps Cleared: 144.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 145.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 146.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 147.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 148.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 149.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 150.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 151.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 152.75
# Tyre: Intermediate, Condition: 0.78, Weather: 20% Wet, Radius: 900, Laps Cleared: 153.75
# Tyre: Intermediate, Condition: 0.67, Weather: 20% Wet, Radius: 900, Laps Cleared: 154.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 155.75
# Tyre: Soft, Condition: 0.90, Weather: 20% Wet, Radius: 900, Laps Cleared: 156.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 157.75
# Tyre: Ultrasoft, Condition: 0.77, Weather: 20% Wet, Radius: 900, Laps Cleared: 158.75
# Tyre: Soft, Condition: 0.90, Weather: 20% Wet, Radius: 900, Laps Cleared: 159.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 160.75
# Tyre: Ultrasoft, Condition: 0.77, Weather: 40% Wet, Radius: 900, Laps Cleared: 161.75
# Tyre: Ultrasoft, Condition: 0.75, Weather: 40% Wet, Radius: 900, Laps Cleared: 161.88
# Tyre: Ultrasoft, Condition: 0.74, Weather: 40% Wet, Radius: 900, Laps Cleared: 162.00
# c:\Users\thede\anaconda3\envs\mitb\lib\site-packages\gym\spaces\box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %% [markdown]
# ## Model testing

# %%
# !pip install sb3-contrib

# %%
import os
from stable_baselines3 import A2C, DQN, PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from sb3_contrib import TQC, QRDQN, MaskablePPO, TRPO, ARS, RecurrentPPO
import pandas as pd

# Define the range of hyperparameters for grid search
learning_rates = [0.0001, 0.001, 0.01]
gammas = [0.95, 0.99, 0.995]

def create_and_train_model(algo_class, env, train_races, save_path, learning_rate, gamma=None):
    vec_env = DummyVecEnv([lambda: env])
    if algo_class==RecurrentPPO:
        model = algo_class("MlpLstmPolicy", vec_env, verbose=1, learning_rate=learning_rate, gamma=gamma)
    elif algo_class==ARS:
        model = algo_class("LinearPolicy", vec_env, verbose=1, learning_rate=learning_rate)
    else:
        model = algo_class("MlpPolicy", vec_env, verbose=1, learning_rate=learning_rate, gamma=gamma)
    model.learn(total_timesteps=168*train_races)
    model.save(save_path)
    return model

def evaluate_model(algo_class, model_filename, env, evalRaces):
    model = algo_class.load(model_filename)
    total_reward = 0
    obs = env.reset()
    for races in range(evalRaces):
        for _ in range(168):
            action, _states = model.predict(obs, deterministic=True)
            obs, reward, done, info = env.step(action)
            total_reward += reward
            env.render()
            if done:
                obs = env.reset()
                break
    return total_reward/evalRaces

# Initialize an empty list to collect the results
results = []

os.makedirs('gym_agents', exist_ok=True)
evalRaces = 1
env = RaceTrackEnv()
trainRaces_list = [1000]

# Process QRDQN
algo_class = QRDQN
algo_name = "QRDQN"
best_reward = float('-inf')  # Initialize with negative infinity

for trainRaces in trainRaces_list:
    for learning_rate in learning_rates:
        for gamma in gammas:
            model_filename = f'gym_agents/{algo_name}_race_track_filepath_{trainRaces}_{learning_rate}_{gamma}'
            try:
                model = algo_class.load(model_filename)
            except:
                model = create_and_train_model(algo_class, env, trainRaces, model_filename, learning_rate, gamma)
            r = evaluate_model(algo_class, model_filename, env, evalRaces)
            print(f'{algo_name} with {trainRaces} train races, lr={learning_rate}, gamma={gamma}: Average reward = {r}')
            if r > best_reward:
                best_reward = r
                best_model_filename = model_filename
            results.append({
                'algorithm': algo_name,
                'train_races': trainRaces,
                'learning_rate': learning_rate,
                'gamma': gamma,
                'average_reward': r
            })

# Save the best model
model.save(f'gym_agents/best_{algo_name}_race_track_filepath')


# Process TRPO
algo_class = TRPO
algo_name = "TRPO"
for trainRaces in trainRaces_list:
    for learning_rate in learning_rates:
        for gamma in gammas:
            model_filename = f'gym_agents/{algo_name}_race_track_filepath_{trainRaces}_{learning_rate}_{gamma}'
            try:
                model = algo_class.load(model_filename)
            except:
                model = create_and_train_model(algo_class, env, trainRaces, model_filename, learning_rate, gamma)
            r = evaluate_model(algo_class, model_filename, env, evalRaces)
            print(f'{algo_name} with {trainRaces} train races, lr={learning_rate}, gamma={gamma}: Average reward = {r}')
            if r > best_reward:
                best_reward = r
                best_model_filename = model_filename
            results.append({
                'algorithm': algo_name,
                'train_races': trainRaces,
                'learning_rate': learning_rate,
                'gamma': gamma,
                'average_reward': r
            })


# Save the best model
model.save(f'gym_agents/best_{algo_name}_race_track_filepath')

# Process ARS
algo_class = ARS
algo_name = "ARS"
for trainRaces in trainRaces_list:
    for learning_rate in learning_rates:
        model_filename = f'gym_agents/{algo_name}_race_track_filepath_{trainRaces}_{learning_rate}'
        try:
            model = algo_class.load(model_filename)
        except:
            model = create_and_train_model(algo_class, env, trainRaces, model_filename, learning_rate)
        r = evaluate_model(algo_class, model_filename, env, evalRaces)
        print(f'{algo_name} with {trainRaces} train races, lr={learning_rate}: Average reward = {r}')
        results.append({
            'algorithm': algo_name,
            'train_races': trainRaces,
            'learning_rate': learning_rate,
            'gamma': None,
            'average_reward': r
        })

# Save the best model
model.save(f'gym_agents/best_{algo_name}_race_track_filepath')

# Process RecurrentPPO
algo_class = RecurrentPPO
algo_name = "RecurrentPPO"
for trainRaces in trainRaces_list:
    for learning_rate in learning_rates:
        for gamma in gammas:
            model_filename = f'gym_agents/{algo_name}_race_track_filepath_{trainRaces}_{learning_rate}_{gamma}'
            try:
                model = algo_class.load(model_filename)
            except:
                model = create_and_train_model(algo_class, env, trainRaces, model_filename, learning_rate, gamma)
                
            r = evaluate_model(algo_class, model_filename, env, evalRaces)
            print(f'{algo_name} with {trainRaces} train races, lr={learning_rate}, gamma={gamma}: Average reward = {r}')
            if r > best_reward:
                best_reward = r
                best_model_filename = model_filename
            results.append({
                'algorithm': algo_name,
                'train_races': trainRaces,
                'learning_rate': learning_rate,
                'gamma': gamma,
                'average_reward': r
            })

# Save the best model
model.save(f'gym_agents/best_{algo_name}_race_track_filepath')

# Convert the results list to a DataFrame
df_results = pd.DataFrame(results)

# Save the DataFrame to a CSV file for easy viewing
df_results.to_csv('gym_agents/hyperparameter_tuning_results.csv', index=False)

# Optionally, display the DataFrame
print(df_results)
# Out:
# c:\Users\thede\anaconda3\envs\mitb\lib\site-packages\gym\spaces\box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Tyre: Intermediate, Condition: 0.98, Weather: 80% Wet, Radius: 900, Laps Cleared: 0.12
# Tyre: Intermediate, Condition: 0.96, Weather: 80% Wet, Radius: 900, Laps Cleared: 0.25
# Tyre: Intermediate, Condition: 0.95, Weather: 80% Wet, Radius: 900, Laps Cleared: 0.38
# Tyre: Intermediate, Condition: 0.93, Weather: 80% Wet, Radius: 900, Laps Cleared: 0.50
# Tyre: Intermediate, Condition: 0.91, Weather: 80% Wet, Radius: 900, Laps Cleared: 0.62
# Tyre: Intermediate, Condition: 0.89, Weather: 80% Wet, Radius: 900, Laps Cleared: 0.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 1.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 2.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 3.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 4.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 5.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 6.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 7.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 8.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 9.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 10.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 11.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 12.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 13.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 14.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 15.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 16.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 17.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 18.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 19.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 20.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 21.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 22.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 23.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 24.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 25.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 26.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 27.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 28.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 29.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 30.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 31.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 32.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 33.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 34.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 35.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 36.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 37.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 38.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 39.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 40.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 41.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 42.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 43.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 44.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 45.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 46.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 47.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 48.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 49.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 50.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 51.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 52.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 53.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 54.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 55.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 56.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 57.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 58.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 59.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 60.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 61.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 62.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 63.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 64.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 65.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 66.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 67.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 68.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 69.75
# Tyre: Fullwet, Condition: 0.90, Weather: 100% Wet, Radius: 900, Laps Cleared: 70.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 71.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 72.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 73.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 74.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 75.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 76.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 77.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 78.75
# Tyre: Fullwet, Condition: 0.90, Weather: 100% Wet, Radius: 900, Laps Cleared: 79.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 80.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 81.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 82.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 83.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 84.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 85.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 86.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 87.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 88.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 89.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 90.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 91.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 92.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 93.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 94.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 95.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 96.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 97.75
# Tyre: Fullwet, Condition: 0.91, Weather: 100% Wet, Radius: 900, Laps Cleared: 98.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 99.75
# Tyre: Fullwet, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 100.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 101.75
# Tyre: Fullwet, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 102.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 103.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 104.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 105.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 106.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 107.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 108.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 109.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 110.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 111.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 112.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 113.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 114.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 115.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 116.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 117.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 118.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 119.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 120.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 121.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 122.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 123.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 124.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 125.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 126.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 127.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 128.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 129.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 130.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 131.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 132.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 133.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 134.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 135.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 136.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 137.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 138.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 139.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 140.75
# Tyre: Fullwet, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 141.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 142.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 143.75
# Tyre: Fullwet, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 144.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 145.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 146.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 147.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 148.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 149.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 150.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 151.75
# Tyre: Fullwet, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 152.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 153.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 154.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 155.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 156.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 157.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 158.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 159.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 160.75
# Tyre: Fullwet, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 161.75
# Tyre: Fullwet, Condition: 0.87, Weather: 40% Wet, Radius: 900, Laps Cleared: 161.88
# QRDQN with 1000 train races, lr=0.0001, gamma=0.95: Average reward = -16213.62055292643
# Tyre: Intermediate, Condition: 0.98, Weather: Dry, Radius: 900, Laps Cleared: 0.12
# Tyre: Intermediate, Condition: 0.96, Weather: Dry, Radius: 900, Laps Cleared: 0.25
# Tyre: Intermediate, Condition: 0.94, Weather: Dry, Radius: 900, Laps Cleared: 0.38
# Tyre: Intermediate, Condition: 0.92, Weather: Dry, Radius: 900, Laps Cleared: 0.50
# Tyre: Intermediate, Condition: 0.91, Weather: Dry, Radius: 900, Laps Cleared: 0.62
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 0.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 1.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 2.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 3.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 4.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 5.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 6.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 7.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 8.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 9.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 10.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 11.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 12.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 13.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 14.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 15.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 16.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 17.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 18.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 19.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 20.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 21.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 22.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 23.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 24.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 25.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 26.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 27.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 28.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 29.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 30.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 31.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 32.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 33.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 34.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 35.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 36.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 37.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 38.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 39.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 40.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 41.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 42.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 43.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 44.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 45.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 46.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 47.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 48.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 49.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 50.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 51.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 52.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 53.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 54.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 55.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 56.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 57.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 58.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 59.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 60.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 61.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 62.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 63.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 64.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 65.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 66.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 67.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 68.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 69.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 70.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 71.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 72.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 73.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 74.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 75.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 76.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 77.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 78.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 79.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 80.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 81.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 82.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 83.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 84.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 85.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 86.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 87.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 88.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 89.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 90.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 91.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 92.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 93.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 94.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 95.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 96.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 97.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 98.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 99.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 100.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 101.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 102.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 103.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 104.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 105.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 106.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 107.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 108.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 109.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 110.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 111.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 112.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 113.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 114.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 115.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 116.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 117.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 118.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 119.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 120.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 121.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 122.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 123.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 124.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 125.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 126.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 127.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 128.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 129.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 130.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 131.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 132.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 133.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 134.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 135.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 136.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 137.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 138.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 139.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 140.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 141.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 142.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 143.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 144.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 145.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 146.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 147.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 148.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 149.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 150.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 151.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 152.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 153.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 154.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 155.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 156.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 157.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 158.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 159.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 160.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 161.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 20% Wet, Radius: 900, Laps Cleared: 161.88
# QRDQN with 1000 train races, lr=0.0001, gamma=0.99: Average reward = -15985.347937899141
# Tyre: Intermediate, Condition: 0.98, Weather: 60% Wet, Radius: 900, Laps Cleared: 0.12
# Tyre: Intermediate, Condition: 0.97, Weather: 60% Wet, Radius: 900, Laps Cleared: 0.25
# Tyre: Intermediate, Condition: 0.95, Weather: 60% Wet, Radius: 900, Laps Cleared: 0.38
# Tyre: Intermediate, Condition: 0.93, Weather: 60% Wet, Radius: 900, Laps Cleared: 0.50
# Tyre: Intermediate, Condition: 0.92, Weather: 60% Wet, Radius: 900, Laps Cleared: 0.62
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 0.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 1.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 2.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 3.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 4.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 5.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 6.75
# Tyre: Ultrasoft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 7.75
# Tyre: Ultrasoft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 8.75
# Tyre: Ultrasoft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 9.75
# Tyre: Ultrasoft, Condition: 0.87, Weather: 80% Wet, Radius: 900, Laps Cleared: 10.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 11.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 12.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 13.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 14.75
# Tyre: Ultrasoft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 15.75
# Tyre: Ultrasoft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 16.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 17.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 18.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 19.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 20.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 21.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 22.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 23.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 24.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 25.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 26.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 27.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 28.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 29.75
# Tyre: Soft, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 30.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 31.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 32.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 33.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 34.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 35.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 36.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 37.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 38.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 39.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 40.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 41.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 42.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 43.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 44.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 45.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 46.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 47.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 48.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 49.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 50.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 51.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 52.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 53.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 54.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 55.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 56.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 57.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 58.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 59.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 60.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 61.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 62.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 63.75
# Tyre: Soft, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 64.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 65.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 66.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 67.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 68.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 69.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 70.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 71.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 72.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 73.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 74.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 75.75
# Tyre: Soft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 76.75
# Tyre: Soft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 77.75
# Tyre: Soft, Condition: 0.90, Weather: 20% Wet, Radius: 900, Laps Cleared: 78.75
# Tyre: Soft, Condition: 0.90, Weather: 20% Wet, Radius: 900, Laps Cleared: 79.75
# Tyre: Soft, Condition: 0.89, Weather: 60% Wet, Radius: 900, Laps Cleared: 80.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 81.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 82.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 83.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 84.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 85.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 86.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 87.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 88.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 89.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 90.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 91.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 92.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 93.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 94.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 95.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 96.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 97.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 98.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 99.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 100.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 101.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 102.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 103.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 104.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 105.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 106.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 107.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 108.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 109.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 110.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 111.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 112.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 113.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 114.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 115.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 116.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 117.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 118.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 119.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 120.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 121.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 122.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 123.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 124.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 125.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 126.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 127.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 128.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 129.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 130.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 131.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 132.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 133.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 134.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 135.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 136.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 137.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 138.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 139.75
# Tyre: Soft, Condition: 0.88, Weather: 60% Wet, Radius: 900, Laps Cleared: 140.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 141.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 142.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 143.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 144.75
# Tyre: Soft, Condition: 0.88, Weather: 100% Wet, Radius: 900, Laps Cleared: 145.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 146.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 147.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 148.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 149.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 150.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 151.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 152.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 153.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 154.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 155.75
# Tyre: Soft, Condition: 0.88, Weather: 80% Wet, Radius: 900, Laps Cleared: 156.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 157.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 158.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 159.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 160.75
# Tyre: Soft, Condition: 0.87, Weather: 100% Wet, Radius: 900, Laps Cleared: 161.75
# Tyre: Soft, Condition: 0.85, Weather: 100% Wet, Radius: 900, Laps Cleared: 161.88
# QRDQN with 1000 train races, lr=0.0001, gamma=0.995: Average reward = -16194.596589715946
# Tyre: Intermediate, Condition: 0.98, Weather: 40% Wet, Radius: 900, Laps Cleared: 0.12
# Tyre: Intermediate, Condition: 0.97, Weather: 40% Wet, Radius: 900, Laps Cleared: 0.25
# Tyre: Intermediate, Condition: 0.95, Weather: 40% Wet, Radius: 900, Laps Cleared: 0.38
# Tyre: Intermediate, Condition: 0.93, Weather: 40% Wet, Radius: 900, Laps Cleared: 0.50
# Tyre: Intermediate, Condition: 0.92, Weather: 40% Wet, Radius: 900, Laps Cleared: 0.62
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 0.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 1.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 2.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 3.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 4.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 5.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 6.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 7.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 8.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 9.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 10.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 11.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 12.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 13.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 14.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 15.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 16.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 17.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 18.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 19.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 20.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 21.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 22.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 23.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 24.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 25.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 26.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 27.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 28.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 29.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 30.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 31.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 32.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 33.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 34.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 35.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 36.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 37.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 38.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 40% Wet, Radius: 900, Laps Cleared: 39.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 40.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 41.75
# Tyre: Ultrasoft, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 42.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 43.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 44.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 45.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 46.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 47.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 48.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 49.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 50.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 51.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 52.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 53.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 54.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 55.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 56.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 57.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 58.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 59.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 60.75
# Tyre: Ultrasoft, Condition: 0.90, Weather: Dry, Radius: 900, Laps Cleared: 61.75
# ...
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 5.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 6.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 7.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 8.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 9.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 10.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 11.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 12.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 13.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 14.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 15.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 16.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 17.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 18.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 19.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 20.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 21.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 22.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 23.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 24.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 25.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 26.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 27.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 28.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 29.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 30.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 31.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 32.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 33.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 34.75
# Tyre: Intermediate, Condition: 0.90, Weather: 20% Wet, Radius: 900, Laps Cleared: 35.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 36.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 37.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 38.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 39.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 40.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 41.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 42.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 43.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 44.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 45.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 46.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 47.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 48.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 49.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 50.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 51.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 52.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 53.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 54.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 55.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 56.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 57.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 58.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 59.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 60.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 61.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 62.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 63.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 64.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 65.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 66.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 67.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 68.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 69.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 70.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 71.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 72.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 73.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 74.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 75.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 76.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 77.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 78.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 79.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 80.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 81.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 82.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 83.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 84.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 85.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 86.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 87.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 88.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 89.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 90.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 91.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 92.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 93.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 94.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 95.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 96.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 97.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 98.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 99.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 100.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 101.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 102.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 103.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 104.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 105.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 106.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 107.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 108.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 109.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 110.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 111.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 112.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 113.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 114.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 115.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 116.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 117.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 118.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 119.75
# Tyre: Intermediate, Condition: 0.90, Weather: 80% Wet, Radius: 900, Laps Cleared: 120.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 121.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 122.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 123.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 124.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 125.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 126.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 127.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 128.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 129.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 130.75
# Tyre: Intermediate, Condition: 0.89, Weather: 100% Wet, Radius: 900, Laps Cleared: 131.75
# Tyre: Intermediate, Condition: 0.89, Weather: 80% Wet, Radius: 900, Laps Cleared: 132.75
# Tyre: Intermediate, Condition: 0.89, Weather: 80% Wet, Radius: 900, Laps Cleared: 133.75
# Tyre: Intermediate, Condition: 0.89, Weather: 80% Wet, Radius: 900, Laps Cleared: 134.75
# Tyre: Intermediate, Condition: 0.89, Weather: 80% Wet, Radius: 900, Laps Cleared: 135.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 136.75
# Tyre: Intermediate, Condition: 0.90, Weather: 60% Wet, Radius: 900, Laps Cleared: 137.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 138.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 139.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 140.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 141.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 142.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 143.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 144.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 145.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 146.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 147.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 148.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 149.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 150.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 151.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 152.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 153.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 154.75
# Tyre: Intermediate, Condition: 0.89, Weather: Dry, Radius: 900, Laps Cleared: 155.75
# Tyre: Intermediate, Condition: 0.89, Weather: 20% Wet, Radius: 900, Laps Cleared: 156.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 157.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 158.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 159.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 160.75
# Tyre: Intermediate, Condition: 0.90, Weather: 40% Wet, Radius: 900, Laps Cleared: 161.75
# Tyre: Intermediate, Condition: 0.88, Weather: 40% Wet, Radius: 900, Laps Cleared: 161.88
# RecurrentPPO with 1000 train races, lr=0.01, gamma=0.995: Average reward = -16155.457147493042
#        algorithm  train_races  learning_rate  gamma  average_reward
# 0          QRDQN         1000         0.0001  0.950   -16213.620553
# 1          QRDQN         1000         0.0001  0.990   -15985.347938
# 2          QRDQN         1000         0.0001  0.995   -16194.596590
# 3          QRDQN         1000         0.0010  0.950   -16044.409284
# 4          QRDQN         1000         0.0010  0.990   -16208.131534
# 5          QRDQN         1000         0.0010  0.995   -16146.013381
# 6          QRDQN         1000         0.0100  0.950   -15996.048674
# 7          QRDQN         1000         0.0100  0.990   -16381.744462
# 8          QRDQN         1000         0.0100  0.995   -16160.416027
# 9           TRPO         1000         0.0001  0.950   -15969.257786
# 10          TRPO         1000         0.0001  0.990   -16142.996806
# 11          TRPO         1000         0.0001  0.995   -16177.781526
# 12          TRPO         1000         0.0010  0.950   -16192.592085
# 13          TRPO         1000         0.0010  0.990   -16161.242311
# 14          TRPO         1000         0.0010  0.995   -16130.322913
# 15          TRPO         1000         0.0100  0.950   -16155.393903
# 16          TRPO         1000         0.0100  0.990   -16158.588707
# 17          TRPO         1000         0.0100  0.995   -54939.682889
# 18           ARS         1000         0.0001    NaN   -16148.555264
# 19           ARS         1000         0.0010    NaN   -16123.949284
# 20           ARS         1000         0.0100    NaN   -16099.671338
# 21  RecurrentPPO         1000         0.0001  0.950   -16126.012556
# 22  RecurrentPPO         1000         0.0001  0.990   -16168.609742
# 23  RecurrentPPO         1000         0.0001  0.995   -54898.755505
# 24  RecurrentPPO         1000         0.0010  0.950   -16266.645351
# 25  RecurrentPPO         1000         0.0010  0.990   -16120.121281
# 26  RecurrentPPO         1000         0.0010  0.995   -16196.840202
# 27  RecurrentPPO         1000         0.0100  0.950   -16067.285562
# 28  RecurrentPPO         1000         0.0100  0.990   -16161.401914
# 29  RecurrentPPO         1000         0.0100  0.995   -16155.457147

# %%
results
# Out:
# [{'algorithm': 'QRDQN',
#   'train_races': 1000,
#   'learning_rate': 0.0001,
#   'gamma': 0.95,
#   'average_reward': -16213.62055292643},
#  {'algorithm': 'QRDQN',
#   'train_races': 1000,
#   'learning_rate': 0.0001,
#   'gamma': 0.99,
#   'average_reward': -15985.347937899141},
#  {'algorithm': 'QRDQN',
#   'train_races': 1000,
#   'learning_rate': 0.0001,
#   'gamma': 0.995,
#   'average_reward': -16194.596589715946},
#  {'algorithm': 'QRDQN',
#   'train_races': 1000,
#   'learning_rate': 0.001,
#   'gamma': 0.95,
#   'average_reward': -16044.409284304047},
#  {'algorithm': 'QRDQN',
#   'train_races': 1000,
#   'learning_rate': 0.001,
#   'gamma': 0.99,
#   'average_reward': -16208.131533600714},
#  {'algorithm': 'QRDQN',
#   'train_races': 1000,
#   'learning_rate': 0.001,
#   'gamma': 0.995,
#   'average_reward': -16146.013381473542},
#  {'algorithm': 'QRDQN',
#   'train_races': 1000,
#   'learning_rate': 0.01,
#   'gamma': 0.95,
#   'average_reward': -15996.048673882044},
#  {'algorithm': 'QRDQN',
#   'train_races': 1000,
#   'learning_rate': 0.01,
#   'gamma': 0.99,
#   'average_reward': -16381.744461515667},
#  {'algorithm': 'QRDQN',
#   'train_races': 1000,
#   'learning_rate': 0.01,
#   'gamma': 0.995,
#   'average_reward': -16160.416026500283},
#  {'algorithm': 'TRPO',
#   'train_races': 1000,
#   'learning_rate': 0.0001,
#   'gamma': 0.95,
#   'average_reward': -15969.257785664675},
#  {'algorithm': 'TRPO',
#   'train_races': 1000,
#   'learning_rate': 0.0001,
#   'gamma': 0.99,
#   'average_reward': -16142.99680640148},
#  {'algorithm': 'TRPO',
#   'train_races': 1000,
#   'learning_rate': 0.0001,
#   'gamma': 0.995,
#   'average_reward': -16177.78152560876},
#  {'algorithm': 'TRPO',
#   'train_races': 1000,
#   'learning_rate': 0.001,
#   'gamma': 0.95,
#   'average_reward': -16192.592085090308},
#  {'algorithm': 'TRPO',
#   'train_races': 1000,
#   'learning_rate': 0.001,
#   'gamma': 0.99,
#   'average_reward': -16161.242311306416},
#  {'algorithm': 'TRPO',
#   'train_races': 1000,
#   'learning_rate': 0.001,
#   'gamma': 0.995,
#   'average_reward': -16130.322912729225},
#  {'algorithm': 'TRPO',
#   'train_races': 1000,
#   'learning_rate': 0.01,
#   'gamma': 0.95,
#   'average_reward': -16155.393902782458},
#  {'algorithm': 'TRPO',
#   'train_races': 1000,
#   'learning_rate': 0.01,
#   'gamma': 0.99,
#   'average_reward': -16158.588707373176},
#  {'algorithm': 'TRPO',
#   'train_races': 1000,
#   'learning_rate': 0.01,
#   'gamma': 0.995,
#   'average_reward': -54939.682889245436},
#  {'algorithm': 'ARS',
#   'train_races': 1000,
#   'learning_rate': 0.0001,
#   'gamma': None,
#   'average_reward': -16148.555263994915},
#  {'algorithm': 'ARS',
#   'train_races': 1000,
#   'learning_rate': 0.001,
#   'gamma': None,
#   'average_reward': -16123.949284345013},
#  {'algorithm': 'ARS',
#   'train_races': 1000,
#   'learning_rate': 0.01,
#   'gamma': None,
#   'average_reward': -16099.671338381659},
#  {'algorithm': 'RecurrentPPO',
#   'train_races': 1000,
#   'learning_rate': 0.0001,
#   'gamma': 0.95,
#   'average_reward': -16126.012555764566},
#  {'algorithm': 'RecurrentPPO',
#   'train_races': 1000,
#   'learning_rate': 0.0001,
#   'gamma': 0.99,
#   'average_reward': -16168.609742307428},
#  {'algorithm': 'RecurrentPPO',
#   'train_races': 1000,
#   'learning_rate': 0.0001,
#   'gamma': 0.995,
#   'average_reward': -54898.75550489256},
#  {'algorithm': 'RecurrentPPO',
#   'train_races': 1000,
#   'learning_rate': 0.001,
#   'gamma': 0.95,
#   'average_reward': -16266.64535101145},
#  {'algorithm': 'RecurrentPPO',
#   'train_races': 1000,
#   'learning_rate': 0.001,
#   'gamma': 0.99,
#   'average_reward': -16120.121281222164},
#  {'algorithm': 'RecurrentPPO',
#   'train_races': 1000,
#   'learning_rate': 0.001,
#   'gamma': 0.995,
#   'average_reward': -16196.840202232435},
#  {'algorithm': 'RecurrentPPO',
#   'train_races': 1000,
#   'learning_rate': 0.01,
#   'gamma': 0.95,
#   'average_reward': -16067.285561728237},
#  {'algorithm': 'RecurrentPPO',
#   'train_races': 1000,
#   'learning_rate': 0.01,
#   'gamma': 0.99,
#   'average_reward': -16161.401914131866},
#  {'algorithm': 'RecurrentPPO',
#   'train_races': 1000,
#   'learning_rate': 0.01,
#   'gamma': 0.995,
#   'average_reward': -16155.457147493042}]

# %%
class Track:
    def __init__(self, car=Car()):
        # self.radius and self.cur_weather are defined in self.reset()
        self.total_laps = 162
        self.car = car
        self.possible_weather = ["Dry", "20% Wet", "40% Wet", "60% Wet", "80% Wet", "100% Wet"]
        self.wetness = {
            "Dry": 0.00, "20% Wet": 0.20, "40% Wet": 0.40, "60% Wet": 0.60, "80% Wet": 0.80, "100% Wet": 1.00
        }
        self.p_transition = {
            "Dry": {
                "Dry": 0.987, "20% Wet": 0.013, "40% Wet": 0.000, "60% Wet": 0.000, "80% Wet": 0.000, "100% Wet": 0.000
            },
            "20% Wet": {
                "Dry": 0.012, "20% Wet": 0.975, "40% Wet": 0.013, "60% Wet": 0.000, "80% Wet": 0.000, "100% Wet": 0.000
            },
            "40% Wet": {
                "Dry": 0.000, "20% Wet": 0.012, "40% Wet": 0.975, "60% Wet": 0.013, "80% Wet": 0.000, "100% Wet": 0.000
            },
            "60% Wet": {
                "Dry": 0.000, "20% Wet": 0.000, "40% Wet": 0.012, "60% Wet": 0.975, "80% Wet": 0.013, "100% Wet": 0.000
            },
            "80% Wet": {
                "Dry": 0.000, "20% Wet": 0.000, "40% Wet": 0.000, "60% Wet": 0.012, "80% Wet": 0.975, "100% Wet": 0.013
            },
            "100% Wet": {
                "Dry": 0.000, "20% Wet": 0.000, "40% Wet": 0.000, "60% Wet": 0.000, "80% Wet": 0.012, "100% Wet": 0.988
            }
        }
        self.reset()
    
    
    def reset(self):
        self.radius = np.random.randint(600,1201)
        # self.radius = 900
        self.cur_weather = np.random.choice(self.possible_weather)
        self.is_done = False
        self.pitstop = False
        self.laps_cleared = 0
        self.car.reset()
        return self._get_state()
    
    
    def _get_state(self):
        return [self.car.tyre, self.car.condition, self.cur_weather, self.radius, self.laps_cleared]
        
    
    def transition(self, action=0):
        """
        Args:
            action (int):
                0. Make a pitstop and fit new ‘Ultrasoft’ tyres
                1. Make a pitstop and fit new ‘Soft’ tyres
                2. Make a pitstop and fit new ‘Intermediate’ tyres
                3. Make a pitstop and fit new ‘Fullwet’ tyres
                4. Continue the next lap without changing tyres
        """
        ## Pitstop time will be added on the first eight of the subsequent lap
        if self.laps_cleared - int(self.laps_cleared) == 0.75 and self.laps_cleared < 161.75:
            total_rewards = 0
            for _ in range(8):
                time_taken = 0
                if self.laps_cleared == int(self.laps_cleared):
                    if self.pitstop:
                        self.car.change_tyre(self.committed_tyre)
                        time_taken += self.car.pitstop_time
                        self.pitstop = False
                
                ## The environment is coded such that only an action taken at the start of the three-quarters mark of each lap matters
                if self.laps_cleared - int(self.laps_cleared) == 0.75:
                    if action < 4:
                        self.pitstop = True
                        self.committed_tyre = self.car.possible_tyres[action]
                    else:
                        self.pitstop = False
                
                self.cur_weather = np.random.choice(
                    self.possible_weather, p=list(self.p_transition[self.cur_weather].values())
                )
                # we assume that degration happens only after a car has travelled the one-eighth lap
                velocity = self.car.get_velocity()
                time_taken += (2*np.pi*self.radius/8) / velocity
                reward = 0 - time_taken
                self.car.degrade(
                    w=self.wetness[self.cur_weather], r=self.radius
                )
                self.laps_cleared += 0.125
                
                if self.laps_cleared == self.total_laps:
                    self.is_done = True
                
                total_rewards += reward
                next_state = self._get_state()
                
            return total_rewards, next_state, self.is_done, velocity
        
        else:
            time_taken = 0
            if self.laps_cleared == int(self.laps_cleared):
                if self.pitstop:
                    self.car.change_tyre(self.committed_tyre)
                    time_taken += self.car.pitstop_time
                    self.pitstop = False
            
            ## The environment is coded such that only an action taken at the start of the three-quarters mark of each lap matters
            if self.laps_cleared - int(self.laps_cleared) == 0.75:
                if action < 4:
                    self.pitstop = True
                    self.committed_tyre = self.car.possible_tyres[action]
                else:
                    self.pitstop = False
            
            self.cur_weather = np.random.choice(
                self.possible_weather, p=list(self.p_transition[self.cur_weather].values())
            )
            # we assume that degration happens only after a car has travelled the one-eighth lap
            velocity = self.car.get_velocity()
            time_taken += (2*np.pi*self.radius/8) / velocity
            reward = 0 - time_taken
            self.car.degrade(
                w=self.wetness[self.cur_weather], r=self.radius
            )
            self.laps_cleared += 0.125
            
            if self.laps_cleared == self.total_laps:
                self.is_done = True
            
            next_state = self._get_state()
            return reward, next_state, self.is_done, velocity

# %%
import os
import pandas as pd
from stable_baselines3 import A2C, DQN, PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from sb3_contrib import TQC, QRDQN, MaskablePPO, TRPO, ARS, RecurrentPPO

# Load the best hyperparameters from the previous step
df_results = pd.read_csv('gym_agents/hyperparameter_tuning_results.csv')

# Update the function to accept total_timesteps as a parameter
def create_and_train_model(algo_class, env, total_timesteps, save_path, learning_rate, gamma=None):
    vec_env = DummyVecEnv([lambda: env])
    if algo_class==RecurrentPPO:
        model = algo_class("MlpLstmPolicy", vec_env, verbose=1, learning_rate=learning_rate, gamma=gamma)
    elif algo_class==ARS:
        model = algo_class("LinearPolicy", vec_env, verbose=1, learning_rate=learning_rate)
    else:
        model = algo_class("MlpPolicy", vec_env, verbose=1, learning_rate=learning_rate, gamma=gamma)
    model.learn(total_timesteps=total_timesteps)
    model.save(save_path)
    return model

# Create environment
env = RaceTrackEnv()

# Function to get the best hyperparameters for a given algorithm
def get_best_hyperparams(algo_name):
    best_row = df_results[df_results['algorithm'] == algo_name].sort_values('average_reward', ascending=False).iloc[0]
    return best_row['learning_rate'], best_row['gamma']

# Function to train and save the model with the best hyperparameters
def train_and_save_best_model(algo_class, algo_name):
    learning_rate, gamma = get_best_hyperparams(algo_name)
    model_filename = f'gym_agents/best_{algo_name}_10000_iterations'
    create_and_train_model(algo_class, env, 10000, model_filename, learning_rate, gamma)

# Train and save the best model for each algorithm
train_and_save_best_model(QRDQN, 'QRDQN')
train_and_save_best_model(TRPO, 'TRPO')
train_and_save_best_model(ARS, 'ARS')
train_and_save_best_model(RecurrentPPO, 'RecurrentPPO')
# Out:
# c:\Users\thede\anaconda3\envs\mitb\lib\site-packages\gym\spaces\box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# c:\Users\thede\anaconda3\envs\mitb\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1874     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 676      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 2044     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1352     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2082     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2028     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2150     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2704     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2174     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3380     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2227     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4056     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2278     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4732     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 2278     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5408     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 2278     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6084     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2291     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2313     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 7436     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2336     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8112     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 2364     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8788     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2382     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9464     |
# ----------------------------------
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 808  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                     |           |
# |    fps                    | 701       |
# |    iterations             | 2         |
# |    time_elapsed           | 5         |
# |    total_timesteps        | 4096      |
# | train/                    |           |
# |    explained_variance     | -0.000707 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00811   |
# |    learning_rate          | 0.0001    |
# |    n_updates              | 1         |
# |    policy_objective       | 0.00531   |
# |    value_loss             | 1.01e+06  |
# -----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 645      |
# |    iterations             | 3        |
# |    time_elapsed           | 9        |
# |    total_timesteps        | 6144     |
# | train/                    |          |
# |    explained_variance     | 5.4e-05  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00658  |
# |    learning_rate          | 0.0001   |
# |    n_updates              | 2        |
# |    policy_objective       | 0.00429  |
# |    value_loss             | 8.94e+05 |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 630      |
# |    iterations             | 4        |
# |    time_elapsed           | 12       |
# |    total_timesteps        | 8192     |
# | train/                    |          |
# |    explained_variance     | 0.000101 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00249  |
# |    learning_rate          | 0.0001   |
# |    n_updates              | 3        |
# |    policy_objective       | 0.00475  |
# |    value_loss             | 9.5e+05  |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 610      |
# |    iterations             | 5        |
# |    time_elapsed           | 16       |
# |    total_timesteps        | 10240    |
# | train/                    |          |
# |    explained_variance     | 7.85e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0052   |
# |    learning_rate          | 0.0001   |
# |    n_updates              | 4        |
# |    policy_objective       | 0.00966  |
# |    value_loss             | 9.52e+05 |
# ----------------------------------------
# Using cpu device
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 169       |
# |    ep_rew_mean     | -2.53e+04 |
# |    return_std      | 1.68e+04  |
# | time/              |           |
# |    fps             | 1626      |
# |    time_elapsed    | 1         |
# |    total_timesteps | 2704      |
# | train/             |           |
# |    delta_std       | 0.05      |
# |    iterations      | 0         |
# |    learning_rate   | 0.01      |
# |    step_size       | 7.44e-08  |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 169       |
# |    ep_rew_mean     | -2.56e+04 |
# |    return_std      | 1.86e+04  |
# | time/              |           |
# |    fps             | 1587      |
# |    time_elapsed    | 3         |
# |    total_timesteps | 5408      |
# | train/             |           |
# |    delta_std       | 0.05      |
# |    iterations      | 1         |
# |    learning_rate   | 0.01      |
# |    step_size       | 6.71e-08  |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 169       |
# |    ep_rew_mean     | -1.91e+04 |
# |    return_std      | 8.01e+03  |
# | time/              |           |
# |    fps             | 1577      |
# |    time_elapsed    | 5         |
# |    total_timesteps | 8112      |
# | train/             |           |
# |    delta_std       | 0.05      |
# |    iterations      | 2         |
# |    learning_rate   | 0.01      |
# |    step_size       | 1.56e-07  |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 169       |
# |    ep_rew_mean     | -1.84e+04 |
# |    return_std      | 1.08e+04  |
# | time/              |           |
# |    fps             | 1526      |
# |    time_elapsed    | 7         |
# |    total_timesteps | 10816     |
# | train/             |           |
# |    delta_std       | 0.05      |
# |    iterations      | 3         |
# |    learning_rate   | 0.01      |
# |    step_size       | 1.15e-07  |
# ----------------------------------
# Using cpu device
# ----------------------------
# | time/              |     |
# |    fps             | 91  |
# |    iterations      | 1   |
# |    time_elapsed    | 1   |
# |    total_timesteps | 128 |
# ----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 256         |
# | train/                  |             |
# |    approx_kl            | 0.015031363 |
# |    clip_fraction        | 0.0547      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | -0.000159   |
# |    learning_rate        | 0.01        |
# |    loss                 | 5.57e+05    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 1.12e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 384         |
# | train/                  |             |
# |    approx_kl            | 0.032095883 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.01        |
# |    loss                 | 3.68e+05    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 7.41e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 4          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 512        |
# | train/                  |            |
# |    approx_kl            | 0.01090882 |
# |    clip_fraction        | 0.0922     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.54      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.01       |
# |    loss                 | 3.58e+05   |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00508   |
# |    value_loss           | 7.22e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 5           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 640         |
# | train/                  |             |
# |    approx_kl            | 0.019697178 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.01        |
# |    loss                 | 5.04e+05    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 1.01e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 6           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 768         |
# | train/                  |             |
# |    approx_kl            | 0.012058464 |
# |    clip_fraction        | 0.0797      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 3.37e+05    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00775    |
# |    value_loss           | 6.79e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 7           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 896         |
# | train/                  |             |
# |    approx_kl            | 0.003735845 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.39e+05    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000659   |
# |    value_loss           | 4.81e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 8            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0055568437 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.01         |
# |    loss                 | 2.17e+05     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00633     |
# |    value_loss           | 4.37e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 9            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 1152         |
# | train/                  |              |
# |    approx_kl            | 0.0150842145 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.01         |
# |    loss                 | 2.22e+05     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0129      |
# |    value_loss           | 4.49e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 10          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.026843127 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 4.04e+05    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 8.13e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 11          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 1408        |
# | train/                  |             |
# |    approx_kl            | 0.008707721 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 3.35e+05    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 6.74e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 12          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.011840522 |
# |    clip_fraction        | 0.0633      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.96e+05    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00429    |
# |    value_loss           | 5.97e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 13          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 1664        |
# | train/                  |             |
# |    approx_kl            | 0.011810154 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.63e+05    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00574    |
# |    value_loss           | 5.3e+05     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 14         |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 1792       |
# | train/                  |            |
# |    approx_kl            | 0.02490496 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.49      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.01       |
# |    loss                 | 3.28e+05   |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0198    |
# |    value_loss           | 6.61e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 15          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 1920        |
# | train/                  |             |
# |    approx_kl            | 0.012583791 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 4.01e+05    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00828    |
# |    value_loss           | 8.08e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 16          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.025614485 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 3.56e+05    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 7.18e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 34           |
# |    iterations           | 17           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 2176         |
# | train/                  |              |
# |    approx_kl            | 0.0033873096 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.55        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.01         |
# |    loss                 | 3.24e+05     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000488    |
# |    value_loss           | 6.52e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 18           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 2304         |
# | train/                  |              |
# |    approx_kl            | 0.0010883147 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.54        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.01         |
# |    loss                 | 6.32e+05     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000379    |
# |    value_loss           | 1.27e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 19          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 2432        |
# | train/                  |             |
# |    approx_kl            | 0.010869903 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.01        |
# |    loss                 | 3.09e+05    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00899    |
# |    value_loss           | 6.22e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 20          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.015735008 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 3.62e+05    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00832    |
# |    value_loss           | 7.29e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 21         |
# |    time_elapsed         | 74         |
# |    total_timesteps      | 2688       |
# | train/                  |            |
# |    approx_kl            | 0.01277188 |
# |    clip_fraction        | 0.0656     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.54      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.01       |
# |    loss                 | 4.46e+05   |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00399   |
# |    value_loss           | 8.98e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 22          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 2816        |
# | train/                  |             |
# |    approx_kl            | 0.006785593 |
# |    clip_fraction        | 0.0156      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 5.38e+05    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00674    |
# |    value_loss           | 1.08e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 23          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 2944        |
# | train/                  |             |
# |    approx_kl            | 0.004193821 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 4.71e+05    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.000749   |
# |    value_loss           | 9.47e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 24           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0030949684 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.01         |
# |    loss                 | 3.1e+05      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00362     |
# |    value_loss           | 6.25e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 25          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 3200        |
# | train/                  |             |
# |    approx_kl            | 0.013556702 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.22e+05    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 4.48e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 26          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 3328        |
# | train/                  |             |
# |    approx_kl            | 0.013378879 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.4e+05     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0077     |
# |    value_loss           | 4.83e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 27          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 3456        |
# | train/                  |             |
# |    approx_kl            | 0.010822985 |
# |    clip_fraction        | 0.0242      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 5.09e+05    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00535    |
# |    value_loss           | 1.02e+06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 37           |
# |    iterations           | 28           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 0.0040695164 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.01         |
# |    loss                 | 2.98e+05     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00408     |
# |    value_loss           | 6e+05        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 29          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 3712        |
# | train/                  |             |
# |    approx_kl            | 0.015675833 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.79e+05    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00641    |
# |    value_loss           | 3.61e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 30          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 3840        |
# | train/                  |             |
# |    approx_kl            | 0.008063594 |
# |    clip_fraction        | 0.0336      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.65e+05    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00561    |
# |    value_loss           | 5.34e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 31          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 3968        |
# | train/                  |             |
# |    approx_kl            | 0.028946673 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 3.42e+05    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0206     |
# |    value_loss           | 6.88e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 32          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015712623 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 3.08e+05    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00781    |
# |    value_loss           | 6.2e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 33          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 4224        |
# | train/                  |             |
# |    approx_kl            | 0.020475674 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.76e+05    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00768    |
# |    value_loss           | 5.55e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 34          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 4352        |
# | train/                  |             |
# |    approx_kl            | 0.024066338 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.15e+05    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00526    |
# |    value_loss           | 4.34e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 35          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 4480        |
# | train/                  |             |
# |    approx_kl            | 0.024250504 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.1e+05     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 4.23e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 36          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.024792006 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.79e+05    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 3.61e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 37          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 4736        |
# | train/                  |             |
# |    approx_kl            | 0.012040977 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.81e+05    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00678    |
# |    value_loss           | 3.65e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 38           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 4864         |
# | train/                  |              |
# |    approx_kl            | 0.0043346947 |
# |    clip_fraction        | 0.00937      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.01         |
# |    loss                 | 2.43e+05     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 4.91e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 39          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 4992        |
# | train/                  |             |
# |    approx_kl            | 0.010455128 |
# |    clip_fraction        | 0.0664      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.01e+05    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00831    |
# |    value_loss           | 4.06e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 40          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.018416222 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.48e+05    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 5.01e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 41         |
# |    time_elapsed         | 139        |
# |    total_timesteps      | 5248       |
# | train/                  |            |
# |    approx_kl            | 0.01576413 |
# |    clip_fraction        | 0.0906     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.01       |
# |    loss                 | 2.86e+05   |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00944   |
# |    value_loss           | 5.75e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 42          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 5376        |
# | train/                  |             |
# |    approx_kl            | 0.022569228 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.01        |
# |    loss                 | 3.43e+05    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 6.91e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 43          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 5504        |
# | train/                  |             |
# |    approx_kl            | 0.007718466 |
# |    clip_fraction        | 0.00937     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.09e+05    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 7.84e-05    |
# |    value_loss           | 4.21e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 44          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 5632        |
# | train/                  |             |
# |    approx_kl            | 0.010340182 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.36e+05    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0084     |
# |    value_loss           | 4.75e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 45         |
# |    time_elapsed         | 152        |
# |    total_timesteps      | 5760       |
# | train/                  |            |
# |    approx_kl            | 0.03479798 |
# |    clip_fraction        | 0.339      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.05      |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.01       |
# |    loss                 | 2.12e+05   |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0122    |
# |    value_loss           | 4.29e+05   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 37           |
# |    iterations           | 46           |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 5888         |
# | train/                  |              |
# |    approx_kl            | 0.0089040715 |
# |    clip_fraction        | 0.0867       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.01         |
# |    loss                 | 1.71e+05     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00261     |
# |    value_loss           | 3.45e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 47          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 6016        |
# | train/                  |             |
# |    approx_kl            | 0.001124328 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.01        |
# |    loss                 | 3.79e+05    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00155     |
# |    value_loss           | 7.63e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 48          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013948554 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.77e+05    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0045     |
# |    value_loss           | 3.57e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 49         |
# |    time_elapsed         | 165        |
# |    total_timesteps      | 6272       |
# | train/                  |            |
# |    approx_kl            | 0.04281358 |
# |    clip_fraction        | 0.355      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.982     |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.01       |
# |    loss                 | 2.28e+05   |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.013     |
# |    value_loss           | 4.6e+05    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 50          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.019468859 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.988      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 3.11e+05    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00678    |
# |    value_loss           | 6.27e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 51          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 6528        |
# | train/                  |             |
# |    approx_kl            | 0.002083843 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.51e+05    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00109    |
# |    value_loss           | 5.05e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# ...
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 59          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 7552        |
# | train/                  |             |
# |    approx_kl            | 0.015507573 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.818      |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.37e+05    |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00415    |
# |    value_loss           | 2.77e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 60           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 0.0021799342 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.758       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.01         |
# |    loss                 | 1.66e+05     |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.000895    |
# |    value_loss           | 3.34e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 61           |
# |    time_elapsed         | 203          |
# |    total_timesteps      | 7808         |
# | train/                  |              |
# |    approx_kl            | 0.0029712813 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.798       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.01         |
# |    loss                 | 2.73e+05     |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00251     |
# |    value_loss           | 5.49e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 62          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 7936        |
# | train/                  |             |
# |    approx_kl            | 7.10967e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.738      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 3.44e+05    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | 0.00108     |
# |    value_loss           | 6.93e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 63          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 8064        |
# | train/                  |             |
# |    approx_kl            | 0.010222346 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.826      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 4.71e+05    |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00456    |
# |    value_loss           | 9.47e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 64          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008497039 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.897      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.26e+05    |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.00785    |
# |    value_loss           | 2.54e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 65           |
# |    time_elapsed         | 216          |
# |    total_timesteps      | 8320         |
# | train/                  |              |
# |    approx_kl            | 0.0014703963 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.849       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.01         |
# |    loss                 | 1.26e+05     |
# |    n_updates            | 640          |
# |    policy_gradient_loss | 0.00101      |
# |    value_loss           | 2.55e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 66           |
# |    time_elapsed         | 220          |
# |    total_timesteps      | 8448         |
# | train/                  |              |
# |    approx_kl            | 0.0017881785 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.831       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.01         |
# |    loss                 | 1.28e+05     |
# |    n_updates            | 650          |
# |    policy_gradient_loss | -0.000558    |
# |    value_loss           | 2.59e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 67          |
# |    time_elapsed         | 220         |
# |    total_timesteps      | 8576        |
# | train/                  |             |
# |    approx_kl            | 0.009247269 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.47e+05    |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.00684    |
# |    value_loss           | 2.97e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 68          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 8704        |
# | train/                  |             |
# |    approx_kl            | 0.014932871 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.813      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.17e+05    |
# |    n_updates            | 670         |
# |    policy_gradient_loss | -0.00509    |
# |    value_loss           | 2.37e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 69          |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 8832        |
# | train/                  |             |
# |    approx_kl            | 0.022934137 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.849      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.56e+05    |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 3.15e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 70          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 8960        |
# | train/                  |             |
# |    approx_kl            | 0.032591604 |
# |    clip_fraction        | 0.505       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.942      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.48e+05    |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 5.01e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 71         |
# |    time_elapsed         | 236        |
# |    total_timesteps      | 9088       |
# | train/                  |            |
# |    approx_kl            | 0.03358341 |
# |    clip_fraction        | 0.517      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.993     |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.01       |
# |    loss                 | 4.32e+05   |
# |    n_updates            | 700        |
# |    policy_gradient_loss | -0.0104    |
# |    value_loss           | 8.69e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 72          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.035845272 |
# |    clip_fraction        | 0.398       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 3.26e+05    |
# |    n_updates            | 710         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 6.56e+05    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 38            |
# |    iterations           | 73            |
# |    time_elapsed         | 240           |
# |    total_timesteps      | 9344          |
# | train/                  |               |
# |    approx_kl            | 0.00074495096 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.01          |
# |    loss                 | 3.31e+05      |
# |    n_updates            | 720           |
# |    policy_gradient_loss | 0.00144       |
# |    value_loss           | 6.67e+05      |
# -------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 74         |
# |    time_elapsed         | 244        |
# |    total_timesteps      | 9472       |
# | train/                  |            |
# |    approx_kl            | 0.04180537 |
# |    clip_fraction        | 0.291      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.01       |
# |    loss                 | 3.18e+05   |
# |    n_updates            | 730        |
# |    policy_gradient_loss | -0.02      |
# |    value_loss           | 6.4e+05    |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 75           |
# |    time_elapsed         | 248          |
# |    total_timesteps      | 9600         |
# | train/                  |              |
# |    approx_kl            | 0.0025335844 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.01         |
# |    loss                 | 2.25e+05     |
# |    n_updates            | 740          |
# |    policy_gradient_loss | -0.00198     |
# |    value_loss           | 4.54e+05     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 76         |
# |    time_elapsed         | 249        |
# |    total_timesteps      | 9728       |
# | train/                  |            |
# |    approx_kl            | 0.02748544 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.01       |
# |    loss                 | 2.05e+05   |
# |    n_updates            | 750        |
# |    policy_gradient_loss | -0.00995   |
# |    value_loss           | 4.14e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 77          |
# |    time_elapsed         | 253         |
# |    total_timesteps      | 9856        |
# | train/                  |             |
# |    approx_kl            | 0.049368717 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.862      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.92e+05    |
# |    n_updates            | 760         |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 3.88e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 78          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 9984        |
# | train/                  |             |
# |    approx_kl            | 0.013611514 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.692      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.99e+05    |
# |    n_updates            | 770         |
# |    policy_gradient_loss | -0.00607    |
# |    value_loss           | 4.02e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 79           |
# |    time_elapsed         | 263          |
# |    total_timesteps      | 10112        |
# | train/                  |              |
# |    approx_kl            | 0.0033174204 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.619       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.01         |
# |    loss                 | 2.19e+05     |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.00451     |
# |    value_loss           | 4.42e+05     |
# ------------------------------------------
